# %%
import missingno as msno
import pandas as pd
import os
from pandas_profiling import ProfileReport

# %%
dfMortes = pd.read_csv(os.getcwd()+'/../data/compiledData/dfMortesCompilado.csv')

# %%
profile = ProfileReport(dfMortes)

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.4.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-11-15 00:08:27.096028&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file("ProfileReportdfMortes.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dfMortes[dfMortes['NUM_BO']=='601'][['DATA_FATO', 'HORA_FATO', 'DESC_TIPOLOCAL',
       'LOGRADOURO', 'NUMERO_LOGRADOURO', 'LATITUDE', 'LONGITUDE',
       'TIPO_PESSOA', 'SEXO_PESSOA', 'IDADE_PESSOA', 'DATA_NASCIMENTO_PESSOA',
       'COR_PELE', 'PROFISSAO', 'NATUREZA_APURADA', 'CRIME']]
# Out:
#        DATA_FATO            HORA_FATO    DESC_TIPOLOCAL     LOGRADOURO  \
# 1210  2020-11-09  1900-01-01 11:50:28  Area não ocupada  RUA DO RETIRO
# 1211  2020-11-09  1900-01-01 11:50:28  Area não ocupada  RUA DO RETIRO
# 1212  2020-11-09  1900-01-01 11:50:28  Area não ocupada  RUA DO RETIRO
# 1213  2020-11-09  1900-01-01 11:50:28  Area não ocupada  RUA DO RETIRO
# 1214  2020-11-09  1900-01-01 11:50:28  Area não ocupada  RUA DO RETIRO
# 1215  2020-11-09  1900-01-01 11:50:28  Area não ocupada  RUA DO RETIRO
# 1216  2020-11-09  1900-01-01 11:50:28  Area não ocupada  RUA DO RETIRO
# 1217  2020-11-09  1900-01-01 11:50:28  Area não ocupada  RUA DO RETIRO
# 1218  2020-11-09  1900-01-01 11:50:28  Area não ocupada  RUA DO RETIRO
# 1219  2020-11-09  1900-01-01 11:50:28  Area não ocupada  RUA DO RETIRO
# 1220  2020-11-09  1900-01-01 11:50:28  Area não ocupada  RUA DO RETIRO
# 1221  2020-11-09  1900-01-01 11:50:28  Area não ocupada  RUA DO RETIRO
# ...
